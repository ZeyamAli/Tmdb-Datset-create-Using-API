# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=ba6b4fb1957e70c09a674f8a495f825b&page=1')

# %%
df1 = pd.DataFrame(response.json()['results'])

# %%
df1[['title','overview','genre_ids']]
# Out:
#                                             title  \
# 0                        The Shawshank Redemption
# 1                                   The Godfather
# 2                           The Godfather Part II
# 3                                Schindler's List
# 4                                    12 Angry Men
# 5                                   Spirited Away
# 6                     Dilwale Dulhania Le Jayenge
# 7                                 The Dark Knight
# 8                                        Parasite
# 9                                  The Green Mile
# 10                                     Your Name.
# 11                                   Pulp Fiction
# 12  The Lord of the Rings: The Return of the King
# 13                      The Count of Monte-Cristo
# 14                                   Forrest Gump
# 15                                     GoodFellas
# 16                 The Good, the Bad and the Ugly
# 17                                  Seven Samurai
# 18                              Impossible Things
# 19                         Grave of the Fireflies
#
#                                              overview  \
# 0   Imprisoned in the 1940s for the double murder ...
# 1   Spanning the years 1945 to 1955, a chronicle o...
# 2   In the continuing saga of the Corleone crime f...
# 3   The true story of how businessman Oskar Schind...
# 4   The defense and the prosecution have rested an...
# 5   A young girl, Chihiro, becomes trapped in a st...
# 6   Raj is a rich, carefree, happy-go-lucky second...
# 7   Batman raises the stakes in his war on crime. ...
# 8   All unemployed, Ki-taek's family takes peculia...
# 9   A supernatural tale set on death row in a Sout...
# 10  High schoolers Mitsuha and Taki are complete s...
# 11  A burger-loving hit man, his philosophical par...
# 12  As armies mass for a final battle that will de...
# 13  Edmond Dantes becomes the target of a sinister...
# 14  A man with a low IQ has accomplished great thi...
# 15  The true story of Henry Hill, a half-Irish, ha...
# 16  While the Civil War rages on between the Union...
# 17  A samurai answers a village's request for prot...
# 18  After the death of her abusive husband, Matild...
# 19  In the final months of World War II, 14-year-o...
#
#                       genre_ids
# 0                      [18, 80]
# 1                      [18, 80]
# 2                      [18, 80]
# 3               [18, 36, 10752]
# 4                          [18]
# 5               [16, 10751, 14]
# 6               [35, 18, 10749]
# 7              [18, 28, 80, 53]
# 8                  [35, 53, 18]
# 9                  [14, 18, 80]
# 10              [16, 10749, 18]
# 11                     [53, 80]
# 12                 [12, 14, 28]
# 13  [12, 36, 28, 18, 10749, 53]
# 14              [35, 18, 10749]
# 15                     [18, 80]
# 16                         [37]
# 17                     [28, 18]
# 18                  [10751, 18]
# 19              [16, 18, 10752]

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,479):
  response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=ba6b4fb1957e70c09a674f8a495f825b&page={}'.format(i))
  temp_df = pd.DataFrame(response.json()['results'])
  df = pd.concat([df, temp_df], ignore_index=True)

df = df[['title','overview','genre_ids']]

# %%
df.shape
# Out:
# (28680, 3)

# %%
df.head()
# Out:
#                       title  \
# 0  The Shawshank Redemption
# 1             The Godfather
# 2     The Godfather Part II
# 3          Schindler's List
# 4              12 Angry Men
#
#                                             overview        genre_ids
# 0  Imprisoned in the 1940s for the double murder ...         [18, 80]
# 1  Spanning the years 1945 to 1955, a chronicle o...         [18, 80]
# 2  In the continuing saga of the Corleone crime f...         [18, 80]
# 3  The true story of how businessman Oskar Schind...  [18, 36, 10752]
# 4  The defense and the prosecution have rested an...             [18]

# %%
df['overview'].head()
# Out:
# 0    Imprisoned in the 1940s for the double murder ...
# 1    Spanning the years 1945 to 1955, a chronicle o...
# 2    In the continuing saga of the Corleone crime f...
# 3    The true story of how businessman Oskar Schind...
# 4    The defense and the prosecution have rested an...
# Name: overview, dtype: object

# %%
df_overview = df['overview']

# %%
df_overview
# Out:
# 0        Imprisoned in the 1940s for the double murder ...
# 1        Spanning the years 1945 to 1955, a chronicle o...
# 2        In the continuing saga of the Corleone crime f...
# 3        The true story of how businessman Oskar Schind...
# 4        The defense and the prosecution have rested an...
#                                ...
# 28675    Gigli is ordered to kidnap the psychologically...
# 28676    Disturbing and mysterious things begin to happ...
# 28677    Old and forgotten, comedian Aldo is brought by...
# 28678    When young Joshua learns that he will be going...
# 28679    In this fast action-packed thriller, Jonathan,...
# Name: overview, Length: 28680, dtype: object
